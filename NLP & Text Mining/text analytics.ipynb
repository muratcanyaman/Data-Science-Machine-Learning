# %% [markdown]
# ## Metin Madenciliği ve Doğal Dil İşleme

# %% [markdown]
# ### Metin Ön İşleme

# %%
import pandas as pd

# %%
metin = """
A Scandal in Bohemia! 01
The Red-Headed League,2
A Case, of Identity 33
The Boscombe Valley Mystery4
The Five Orange Pips1
The Man with? the Twisted Lip
The Adventure of the Blue Carbuncle
The Adventure of the Speckled Band
The Adventure of the Engineer's Thumb
The Adventure of the Noble Bachelor
The Adventure of the Beryl Coronet
The Adventure of the Copper Beeches"""

metin
# Out:
# "\nA Scandal in Bohemia! 01\nThe Red-Headed League,2\nA Case, of Identity 33\nThe Boscombe Valley Mystery4\nThe Five Orange Pips1\nThe Man with? the Twisted Lip\nThe Adventure of the Blue Carbuncle\nThe Adventure of the Speckled Band\nThe Adventure of the Engineer's Thumb\nThe Adventure of the Noble Bachelor\nThe Adventure of the Beryl Coronet\nThe Adventure of the Copper Beeches"

# %%
#metin verisini düzenlemek || df/array/seri'ye çevirmek

# %%
v_metin = metin.split("\n")

# %%
v_metin
# Out:
# ['',
#  'A Scandal in Bohemia! 01',
#  'The Red-Headed League,2',
#  'A Case, of Identity 33',
#  'The Boscombe Valley Mystery4',
#  'The Five Orange Pips1',
#  'The Man with? the Twisted Lip',
#  'The Adventure of the Blue Carbuncle',
#  'The Adventure of the Speckled Band',
#  "The Adventure of the Engineer's Thumb",
#  'The Adventure of the Noble Bachelor',
#  'The Adventure of the Beryl Coronet',
#  'The Adventure of the Copper Beeches']

# %%
v = pd.Series(v_metin)

# %%
v
# Out:
# 0
# 1                  A Scandal in Bohemia! 01
# 2                   The Red-Headed League,2
# 3                    A Case, of Identity 33
# 4              The Boscombe Valley Mystery4
# 5                     The Five Orange Pips1
# 6             The Man with? the Twisted Lip
# 7       The Adventure of the Blue Carbuncle
# 8        The Adventure of the Speckled Band
# 9     The Adventure of the Engineer's Thumb
# 10      The Adventure of the Noble Bachelor
# 11       The Adventure of the Beryl Coronet
# 12      The Adventure of the Copper Beeches
# dtype: object

# %%
text_vector = v[1 : len(v)]

# %%
text_vector
# Out:
# 1                  A Scandal in Bohemia! 01
# 2                   The Red-Headed League,2
# 3                    A Case, of Identity 33
# 4              The Boscombe Valley Mystery4
# 5                     The Five Orange Pips1
# 6             The Man with? the Twisted Lip
# 7       The Adventure of the Blue Carbuncle
# 8        The Adventure of the Speckled Band
# 9     The Adventure of the Engineer's Thumb
# 10      The Adventure of the Noble Bachelor
# 11       The Adventure of the Beryl Coronet
# 12      The Adventure of the Copper Beeches
# dtype: object

# %%
mdf = pd.DataFrame(text_vector, columns = ["stories"])

# %%
mdf
# Out:
#                                   stories
# 1                A Scandal in Bohemia! 01
# 2                 The Red-Headed League,2
# 3                  A Case, of Identity 33
# 4            The Boscombe Valley Mystery4
# 5                   The Five Orange Pips1
# 6           The Man with? the Twisted Lip
# 7     The Adventure of the Blue Carbuncle
# 8      The Adventure of the Speckled Band
# 9   The Adventure of the Engineer's Thumb
# 10    The Adventure of the Noble Bachelor
# 11     The Adventure of the Beryl Coronet
# 12    The Adventure of the Copper Beeches

# %%
#büyük küçük harf dönüşümü

# %%
d_mdf = mdf.copy()

# %%
d_mdf
# Out:
#                                   stories
# 1                A Scandal in Bohemia! 01
# 2                 The Red-Headed League,2
# 3                  A Case, of Identity 33
# 4            The Boscombe Valley Mystery4
# 5                   The Five Orange Pips1
# 6           The Man with? the Twisted Lip
# 7     The Adventure of the Blue Carbuncle
# 8      The Adventure of the Speckled Band
# 9   The Adventure of the Engineer's Thumb
# 10    The Adventure of the Noble Bachelor
# 11     The Adventure of the Beryl Coronet
# 12    The Adventure of the Copper Beeches

# %%
d_mdf["stories"] = d_mdf["stories"].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %%
d_mdf
# Out:
#                                   stories
# 1                a scandal in bohemia! 01
# 2                 the red-headed league,2
# 3                  a case, of identity 33
# 4            the boscombe valley mystery4
# 5                   the five orange pips1
# 6           the man with? the twisted lip
# 7     the adventure of the blue carbuncle
# 8      the adventure of the speckled band
# 9   the adventure of the engineer's thumb
# 10    the adventure of the noble bachelor
# 11     the adventure of the beryl coronet
# 12    the adventure of the copper beeches

# %% [markdown]
# ## Temel String İşlemleri

# %% [markdown]
# ### Oluşturma, Biçimlendirme

# %%
isim = "mcy"

# %%
3 * isim
# Out:
# 'mcymcymcy'

# %%
"mcy" + "ali"
# Out:
# 'mcyali'

# %%
"K" + isim[1:]
# Out:
# 'Kcy'

# %%
isimler = ["ali", "veli", "ayse"]

# %%
for i in isimler:
    print("İsim:", i, sep  = "")
# Out:
# İsim:ali
# İsim:veli
# İsim:ayse

# %%
for i in isimler:
    print("_", i[0:], sep  = "")
# Out:
# _ali
# _veli
# _ayse

# %%
print(*enumerate(isimler))
# Out:
# (0, 'ali') (1, 'veli') (2, 'ayse')

# %%
for i in enumerate(isimler):
    print(i)
# Out:
# (0, 'ali')
# (1, 'veli')
# (2, 'ayse')

# %%
for i in enumerate("isimler"):
    print(i)
# Out:
# (0, 'i')
# (1, 's')
# (2, 'i')
# (3, 'm')
# (4, 'l')
# (5, 'e')
# (6, 'r')

# %% [markdown]
# for i in enumerate(isimler, 1):
#     print(i)

# %% [markdown]
# ### Dizi içi Tip Sorgulamaları

# %%
"mcy".isalpha()
# Out:
# True

# %%
"mcy30".isalpha()
# Out:
# False

# %%
"123".isnumeric()
# Out:
# True

# %%
"123".isdigit()
# Out:
# True

# %%
"123mcy".isalnum()
# Out:
# True

# %% [markdown]
# ### Elemanlarına ve Eleman Indexlerine Erişmek

# %%
isim = "muratcanyaman"

# %%
isim
# Out:
# 'muratcanyaman'

# %%
isim[0:2]
# Out:
# 'mu'

# %%
isim.index("n")
# Out:
# 7

# %%
isim.index("a")
# Out:
# 3

# %%
isim.index("a", 4)
# Out:
# 6

# %% [markdown]
# ### Başlangıç ve Bitiş Karakterlerini Sorgulamak: startswith() & endswith()

# %%
isim = "Murat Can Yaman"

# %%
isim.startswith("a")
# Out:
# False

# %%
isim.startswith("m")
# Out:
# False

# %%
isim.startswith("M")
# Out:
# True

# %%
isim.endswith("n")
# Out:
# True

# %%
#count

# %%
isim.count("a")
# Out:
# 4

# %%
#sorted

# %%
sorted("kitap")
# Out:
# ['a', 'i', 'k', 'p', 't']

# %%
print(*sorted("kalem"), sep = "")
# Out:
# aeklm

# %% [markdown]
# ### Karakterleri Bölmek

# %%
isim = "Murat Can Yaman"

# %%
isim.split()
# Out:
# ['Murat', 'Can', 'Yaman']

# %%
isim.split("a")
# Out:
# ['Mur', 't C', 'n Y', 'm', 'n']

# %%
isim.split(",")
# Out:
# ['Murat Can Yaman']

# %% [markdown]
# ### Büyük Küçük Harf İşlemleri

# %%
isim = "Murat Can Yaman"

# %%
isim.upper()
# Out:
# 'MURAT CAN YAMAN'

# %%
isim.lower()
# Out:
# 'murat can yaman'

# %%
isim.upper().lower()
# Out:
# 'murat can yaman'

# %%
isim_b = isim.upper()

# %%
isim_b.islower()
# Out:
# False

# %%
isim_b.isupper()
# Out:
# True

# %% [markdown]
# ### capitalize() & title() & swapcase()

# %%
isim = "murat can yaman"

# %%
isim.capitalize()
# Out:
# 'Murat can yaman'

# %%
isim.title()
# Out:
# 'Murat Can Yaman'

# %%
isim = "MURAT can YAMAN"

# %%
isim.swapcase()
# Out:
# 'murat CAN yaman'

# %% [markdown]
# ### İstenmeyen Karakterleri Kırpmak: strip(), lstrip(), rstrip()

# %%
isim = " murat "

# %%
isim.strip()
# Out:
# 'murat'

# %%
isim = "*murat*"

# %%
isim.strip("*")
# Out:
# 'murat'

# %%
isim.rstrip("*")
# Out:
# '*murat'

# %%
isim.lstrip("*")
# Out:
# 'murat*'

# %% [markdown]
# ## join: Bölünmüş İfadelerin Birleştirilmesi

# %%
isim = "Murat Can Yaman"

# %%
ayrik = isim.split()

# %%
ayrik
# Out:
# ['Murat', 'Can', 'Yaman']

# %%
joiner = " "

# %%
joiner.join(ayrik)
# Out:
# 'Murat Can Yaman'

# %% [markdown]
# ### Eleman Değiştirme: replace(), str.maketrans(), translate()

# %%
isim = "Kemal"

# %%
isim.replace("K", "C")
# Out:
# 'Cemal'

# %%
ifade = "Bu ifade içerisinde bağzı TÜrkçe karakterler vardır"

# %%
duzeltilecek_harfler = "çÇğĞıİöÖşŞüÜ"
duzeltilmis_harfler = "cCgGiIoOsSuU"

# %%
alfabe_duzeltme = str.maketrans(duzeltilecek_harfler, duzeltilmis_harfler)

# %%
ifade.translate(alfabe_duzeltme)
# Out:
# 'Bu ifade icerisinde bagzi TUrkce karakterler vardir'

# %% [markdown]
# ### contains()

# %%
import pandas as pd
isimler = ["ayse", "Ayşe", "ali", "aali", "Ali", "veli", "mehmet", "berkcan"]
v = pd.Series(isimler)

# %%
v
# Out:
# 0       ayse
# 1       Ayşe
# 2        ali
# 3       aali
# 4        Ali
# 5       veli
# 6     mehmet
# 7    berkcan
# dtype: object

# %%
v.str.contains("al")
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
v[v.str.contains("al")]
# Out:
# 2     ali
# 3    aali
# dtype: object

# %%
v.str.contains("[Aa]li").sum()
# Out:
# np.int64(3)

# %% [markdown]
# ### Noktalama İşaretlerinin Silinmesi

# %%
d_mdf
# Out:
#                                   stories
# 1                a scandal in bohemia! 01
# 2                 the red-headed league,2
# 3                  a case, of identity 33
# 4            the boscombe valley mystery4
# 5                   the five orange pips1
# 6           the man with? the twisted lip
# 7     the adventure of the blue carbuncle
# 8      the adventure of the speckled band
# 9   the adventure of the engineer's thumb
# 10    the adventure of the noble bachelor
# 11     the adventure of the beryl coronet
# 12    the adventure of the copper beeches

# %%
type(d_mdf)
# Out:
# pandas.core.frame.DataFrame

# %%
d_mdf["stories"] = d_mdf["stories"].str.replace(r"[^\w\s]", "", regex = True)

# %%
d_mdf
# Out:
#                                  stories
# 1                a scandal in bohemia 01
# 2                  the redheaded league2
# 3                  a case of identity 33
# 4           the boscombe valley mystery4
# 5                  the five orange pips1
# 6           the man with the twisted lip
# 7    the adventure of the blue carbuncle
# 8     the adventure of the speckled band
# 9   the adventure of the engineers thumb
# 10   the adventure of the noble bachelor
# 11    the adventure of the beryl coronet
# 12   the adventure of the copper beeches

# %% [markdown]
# ### Sayıların Silinmesi

# %%
d_mdf["stories"] = d_mdf["stories"].str.replace(r"\d","", regex = True)

# %%
d_mdf
# Out:
#                                  stories
# 1                  a scandal in bohemia
# 2                   the redheaded league
# 3                    a case of identity
# 4            the boscombe valley mystery
# 5                   the five orange pips
# 6           the man with the twisted lip
# 7    the adventure of the blue carbuncle
# 8     the adventure of the speckled band
# 9   the adventure of the engineers thumb
# 10   the adventure of the noble bachelor
# 11    the adventure of the beryl coronet
# 12   the adventure of the copper beeches

# %% [markdown]
# ### Stopwords'lerin Silinmesi

# %%
import nltk

# %%
from nltk.corpus import stopwords

# %%
sw = stopwords.words("english")

# %%
d_mdf["stories"] = d_mdf["stories"].apply(lambda x: " ".join(x for x in x.split() if x not in sw))

# %%
d_mdf
# Out:
#                       stories
# 1             scandal bohemia
# 2            redheaded league
# 3               case identity
# 4     boscombe valley mystery
# 5            five orange pips
# 6             man twisted lip
# 7    adventure blue carbuncle
# 8     adventure speckled band
# 9   adventure engineers thumb
# 10   adventure noble bachelor
# 11    adventure beryl coronet
# 12   adventure copper beeches

# %% [markdown]
# ### Az geçen kelimelerin silinmesi

# %%
type(d_mdf)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.Series(" ".join(d_mdf["stories"]).split()).value_counts()
# Out:
# adventure    6
# scandal      1
# redheaded    1
# bohemia      1
# case         1
# identity     1
# boscombe     1
# valley       1
# mystery      1
# five         1
# orange       1
# league       1
# pips         1
# man          1
# twisted      1
# lip          1
# blue         1
# carbuncle    1
# speckled     1
# band         1
# engineers    1
# thumb        1
# noble        1
# bachelor     1
# beryl        1
# coronet      1
# copper       1
# beeches      1
# Name: count, dtype: int64

# %%
delete = pd.Series(" ".join(d_mdf["stories"]).split()).value_counts()[-3:]

# %%
delete
# Out:
# coronet    1
# copper     1
# beeches    1
# Name: count, dtype: int64

# %%
d_mdf["stories"] = d_mdf["stories"].apply(lambda x: " ".join(x for x in x.split() if x not in delete))

# %%
d_mdf
# Out:
#                       stories
# 1             scandal bohemia
# 2            redheaded league
# 3               case identity
# 4     boscombe valley mystery
# 5            five orange pips
# 6             man twisted lip
# 7    adventure blue carbuncle
# 8     adventure speckled band
# 9   adventure engineers thumb
# 10   adventure noble bachelor
# 11            adventure beryl
# 12                  adventure

# %% [markdown]
# ### Tokenization

# %%
import textblob

# %%
from textblob import TextBlob

# %%
d_mdf["stories"] = d_mdf["stories"].apply(lambda x: TextBlob(x).words)

# %%
d_mdf
# Out:
#                           stories
# 1              [scandal, bohemia]
# 2             [redheaded, league]
# 3                [case, identity]
# 4     [boscombe, valley, mystery]
# 5            [five, orange, pips]
# 6             [man, twisted, lip]
# 7    [adventure, blue, carbuncle]
# 8     [adventure, speckled, band]
# 9   [adventure, engineers, thumb]
# 10   [adventure, noble, bachelor]
# 11             [adventure, beryl]
# 12                    [adventure]

# %% [markdown]
# ### Stemming

# %%
from nltk.stem import PorterStemmer

# %%
st = PorterStemmer()

# %%
d_mdf["stories"].apply(
    lambda x: " ".join(st.stem(i) for i in x)
)
# Out:
# 1            scandal bohemia
# 2              redhead leagu
# 3                 case ident
# 4     boscomb valley mysteri
# 5             five orang pip
# 6              man twist lip
# 7     adventur blue carbuncl
# 8       adventur speckl band
# 9       adventur engin thumb
# 10    adventur nobl bachelor
# 11            adventur beryl
# 12                  adventur
# Name: stories, dtype: object

# %% [markdown]
# ### Lemmatization

# %%
from textblob import Word

# %%
d_mdf["stories"] = d_mdf["stories"].apply(lambda x: " ".join(Word(word).lemmatize() for word in x))

# %%
mdf["stories"][1:5]
# Out:
# 2         The Red-Headed League,2
# 3          A Case, of Identity 33
# 4    The Boscombe Valley Mystery4
# 5           The Five Orange Pips1
# Name: stories, dtype: object

# %%
d_mdf["stories"][1:5]
# Out:
# 2           redheaded league
# 3              case identity
# 4    boscombe valley mystery
# 5            five orange pip
# Name: stories, dtype: object

# %% [markdown]
# ## NLP Uygulamaları

# %% [markdown]
# ### N-Gram

# %%
from textblob import TextBlob

# %%
text = """Bu örneği anlaşılabilmesi için daha uzun bir metin üzerinden göstereceğim.
N-gram'lar birlikte kullanılan kelimelerin kombinasyonlarını gösterir"""

# %%
TextBlob(text).ngrams(3)
# Out:
# [WordList(['Bu', 'örneği', 'anlaşılabilmesi']),
#  WordList(['örneği', 'anlaşılabilmesi', 'için']),
#  WordList(['anlaşılabilmesi', 'için', 'daha']),
#  WordList(['için', 'daha', 'uzun']),
#  WordList(['daha', 'uzun', 'bir']),
#  WordList(['uzun', 'bir', 'metin']),
#  WordList(['bir', 'metin', 'üzerinden']),
#  WordList(['metin', 'üzerinden', 'göstereceğim']),
#  WordList(['üzerinden', 'göstereceğim', "N-gram'lar"]),
#  WordList(['göstereceğim', "N-gram'lar", 'birlikte']),
#  WordList(["N-gram'lar", 'birlikte', 'kullanılan']),
#  WordList(['birlikte', 'kullanılan', 'kelimelerin']),
#  WordList(['kullanılan', 'kelimelerin', 'kombinasyonlarını']),
#  WordList(['kelimelerin', 'kombinasyonlarını', 'gösterir'])]

# %% [markdown]
# ### Part of Speech Tagging (POS)

# %%
import nltk

# %%
d_mdf
# Out:
#                      stories
# 1            scandal bohemia
# 2           redheaded league
# 3              case identity
# 4    boscombe valley mystery
# 5            five orange pip
# 6            man twisted lip
# 7   adventure blue carbuncle
# 8    adventure speckled band
# 9   adventure engineer thumb
# 10  adventure noble bachelor
# 11           adventure beryl
# 12                 adventure

# %%
TextBlob(d_mdf["stories"][2]).tags
# Out:
# [('redheaded', 'VBN'), ('league', 'NN')]

# %%
d_mdf["stories"].apply(lambda x: TextBlob(x).tags)
# Out:
# 1                     [(scandal, NN), (bohemia, NN)]
# 2                   [(redheaded, VBN), (league, NN)]
# 3                       [(case, NN), (identity, NN)]
# 4      [(boscombe, NN), (valley, NN), (mystery, NN)]
# 5              [(five, CD), (orange, NN), (pip, NN)]
# 6             [(man, NN), (twisted, VBD), (lip, NN)]
# 7     [(adventure, NN), (blue, JJ), (carbuncle, NN)]
# 8     [(adventure, NN), (speckled, VBD), (band, NN)]
# 9     [(adventure, NN), (engineer, NN), (thumb, NN)]
# 10    [(adventure, NN), (noble, JJ), (bachelor, NN)]
# 11                    [(adventure, NN), (beryl, NN)]
# 12                                 [(adventure, NN)]
# Name: stories, dtype: object

# %% [markdown]
# ### Chunking (shallow parsing)

# %%
sentence = "R and Python are useful data science tools for the new or old data scientists who eager to do efficent data science task."

# %%
pos = TextBlob(sentence).tags

# %%
pos
# Out:
# [('R', 'NNP'),
#  ('and', 'CC'),
#  ('Python', 'NNP'),
#  ('are', 'VBP'),
#  ('useful', 'JJ'),
#  ('data', 'NNS'),
#  ('science', 'NN'),
#  ('tools', 'NNS'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('new', 'JJ'),
#  ('or', 'CC'),
#  ('old', 'JJ'),
#  ('data', 'NNS'),
#  ('scientists', 'NNS'),
#  ('who', 'WP'),
#  ('eager', 'VBP'),
#  ('to', 'TO'),
#  ('do', 'VB'),
#  ('efficent', 'JJ'),
#  ('data', 'NNS'),
#  ('science', 'NN'),
#  ('task', 'NN')]

# %%
reg_exp = "NP: {<DT>?<JJ>*<NN>}"
rp = nltk.RegexpParser(reg_exp)

# %%
results = rp.parse(pos)

# %%
print(results)
# Out:
# (S
#   R/NNP
#   and/CC
#   Python/NNP
#   are/VBP
#   useful/JJ
#   data/NNS
#   (NP science/NN)
#   tools/NNS
#   for/IN
#   the/DT
#   new/JJ
#   or/CC
#   old/JJ
#   data/NNS
#   scientists/NNS
#   who/WP
#   eager/VBP
#   to/TO
#   do/VB
#   efficent/JJ
#   data/NNS
#   (NP science/NN)
#   (NP task/NN))

# %%
results.draw()

# %% [markdown]
# ### Named Entity Recognation

# %%
from nltk import word_tokenize, pos_tag, ne_chunk

# %%
sentence = "Hadley is creative people who work for R Studio AND he attented conference at Newyork last year."

# %%
print(ne_chunk(pos_tag(word_tokenize(sentence))))
# Out:
# (S
#   (GPE Hadley/NNP)
#   is/VBZ
#   creative/JJ
#   people/NNS
#   who/WP
#   work/VBP
#   for/IN
#   (ORGANIZATION R/NNP Studio/NNP)
#   AND/CC
#   he/PRP
#   attented/VBD
#   conference/NN
#   at/IN
#   (ORGANIZATION Newyork/NNP)
#   last/JJ
#   year/NN
#   ./.)

# %% [markdown]
# ## Matematiksel İşlemler ve Basit Özellik Çıkarımı

# %%
d_mdf["stories"]
# Out:
# 1              scandal bohemia
# 2             redheaded league
# 3                case identity
# 4      boscombe valley mystery
# 5              five orange pip
# 6              man twisted lip
# 7     adventure blue carbuncle
# 8      adventure speckled band
# 9     adventure engineer thumb
# 10    adventure noble bachelor
# 11             adventure beryl
# 12                   adventure
# Name: stories, dtype: object

# %% [markdown]
# ### Harf/Karakter Sayısı

# %%
o_mdf = d_mdf.copy()

# %%
o_mdf["letter_count"] = d_mdf["stories"].str.len()

# %%
o_mdf
# Out:
#                      stories  letter_count
# 1            scandal bohemia            15
# 2           redheaded league            16
# 3              case identity            13
# 4    boscombe valley mystery            23
# 5            five orange pip            15
# 6            man twisted lip            15
# 7   adventure blue carbuncle            24
# 8    adventure speckled band            23
# 9   adventure engineer thumb            24
# 10  adventure noble bachelor            24
# 11           adventure beryl            15
# 12                 adventure             9

# %% [markdown]
# ### Kelime Sayısı

# %%
o_mdf["word_count"] = o_mdf["stories"].apply(lambda x: len(str(x).split(" ")))

# %%
o_mdf
# Out:
#                      stories  letter_count  word_count
# 1            scandal bohemia            15           2
# 2           redheaded league            16           2
# 3              case identity            13           2
# 4    boscombe valley mystery            23           3
# 5            five orange pip            15           3
# 6            man twisted lip            15           3
# 7   adventure blue carbuncle            24           3
# 8    adventure speckled band            23           3
# 9   adventure engineer thumb            24           3
# 10  adventure noble bachelor            24           3
# 11           adventure beryl            15           2
# 12                 adventure             9           1

# %% [markdown]
# ### Özel Karakterleri Yakalamak & Saydırmak

# %%
o_mdf["char_count"] = o_mdf["stories"].apply(lambda x: len([x for x in x.split()
                                      if x.startswith("adventure")]))

# %%
o_mdf
# Out:
#                      stories  letter_count  word_count  char_count
# 1            scandal bohemia            15           2           0
# 2           redheaded league            16           2           0
# 3              case identity            13           2           0
# 4    boscombe valley mystery            23           3           0
# 5            five orange pip            15           3           0
# 6            man twisted lip            15           3           0
# 7   adventure blue carbuncle            24           3           1
# 8    adventure speckled band            23           3           1
# 9   adventure engineer thumb            24           3           1
# 10  adventure noble bachelor            24           3           1
# 11           adventure beryl            15           2           1
# 12                 adventure             9           1           1

# %% [markdown]
# ### Sayıları Yakalamak & Saydırmak

# %%
mdf["stories"].apply(lambda x: len([x for x in x.split()
                                      if x.isdigit()]))
# Out:
# 1     1
# 2     0
# 3     1
# 4     0
# 5     0
# 6     0
# 7     0
# 8     0
# 9     0
# 10    0
# 11    0
# 12    0
# Name: stories, dtype: int64
