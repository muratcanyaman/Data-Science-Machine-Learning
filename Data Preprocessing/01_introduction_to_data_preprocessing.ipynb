# %% [markdown]
# ## Veri Ön İşlemeye Giriş

# %% [markdown]
# *Makine öğrenmesinin amacı genellenebilir yapılar ortaya koymaktır. Belirli olaylar gözlemlendiğinde belirli sonuçları vermektedir.*<br>

# %% [markdown]
# *Makine Öğrenmesi modelleri esasında veriden beslenir. Veri ne kadar iyi olursa model de kendisini o kadar iyi eğitir.*

# %% [markdown]
# *Uçtan uca Veri Bilimi proje sürecinin %80'i veri hazırlama ve ön işleme, %20'si ise veriye uygun model seçimi ve eğitimidir.*

# %% [markdown]
# ### Adımlar

# %% [markdown]
# - **Veri Temizleme (Data Cleaning / Cleansing)**
#   - Gürültülü Veri (Noisy Data)
#   - Eksik Veri Analizi (Missing Data Analysis)
#   - Aykırı Gözlem Analizi (Outlier Analysis)
#
# - **Veri Standardizasyonu (Data Standardization, Feature Scaling)**
#   - 0-1 Dönüşümü (Normalization)
#   - z-skoruna Dönüştürme (Standardization)
#   - Logaritmik Dönüşüm (Log Transformation)
#
# - **Veri İndirgeme (Data Reduction)**
#   - Gözlem (Observation) Sayısının Azaltılması
#   - Değişken (Variable) Sayısının Azaltılması
#
# - **Değişken Dönüşümleri (Variable Transformation)**
#   - Sürekli değişkenlerde dönüşümler
#   - Kategorik değişkenlerde dönüşümler

# %% [markdown]
# *En önemli adım veri temizleme adımıdır.*
