# %% [markdown]
# ## Model Başarı Değerlendirme Yöntemleri

# %% [markdown]
# *Model eğitimi sonucu elde ettiğimiz tahmini değerler ile gerçek değer arasındaki farkların ortalaması alınıp elde edilen hata oranına göre modelin başarısı değerlendirilir. Problemden probleme bu değerlendirme işlemi birtakım farklılıklar gösterse de mantık aynıdır.*

# %% [markdown]
# ### Regresyon Problemleri için Başarı Değerlendirme Yöntemleri

# %% [markdown]
# #### Hata Karelerinin Ortalaması Yöntemi (MSE)

# %% [markdown]
# <div align="center">
#     <img src="image XII.png" width="500">
# </div>

# %% [markdown]
# #### Hata Karelerinin Ortalamasının Karekökü Yöntemi (RMSE)

# %% [markdown]
# <div align="center">
#     <img src="image XIII.png" width="500">
# </div>

# %% [markdown]
# #### Mutlak Hata Ortalaması (MAE)

# %% [markdown]
# <div align="center">
#     <img src="image XIV.png" width="500">
# </div>

# %% [markdown]
# *Ortalama Kare Hata'yı örnek bir veri seti üzerinden anlatalım:*

# %% [markdown]
# <div align="center">
#     <img src="image XV.png" width="500">
# </div>

# %% [markdown]
# *x1,x2 ve x3 değişkenlerini kullanarak bir regresyon modeli geliştirdiğimizi düşünelim. Bu modele değişkenleri parametre olarak tekrar girdiğimizde y_sapka tahmini değişkeni oluşturduk. y değişkeni ise gerçek değerler. Her gözlem biriminde bu gerçek değer ile tahmini değer farkını aldık. Oluşan fark değeri her bir gözlem için hata değerini ifade ediyor. Farkın negatif veya pozitif olması önemli değil. Farkın negatif veya pozitif olması aynı şey. İşaret sadece yönlü uzaklığı temsil ediyor. Bu yüzden aradaki farkların karesini alıyoruz. Hepsinin ortalamasını aldığımız zaman ortalama hata değerini buluyoruz. Örneğin bir gözlem biriminde gerçek değer 7.00 olsun. Benim eğittiğim modelin yapacağı tahmin gerçek değerden en fazla +-0.37'lik bir sapma miktarına sahip olur.*

# %% [markdown]
# ### Sınıflandırma Problemleri için Başarı Değerlendirme Yöntemleri

# %% [markdown]
# #### Karışıklık Matrisi

# %% [markdown]
# <div align="center">
#     <img src="image XVI.png" width="500">
# </div>

# %% [markdown]
# *Bir sınıflandırma probleminde;*<br>
# *Sınıf değerimiz gerçekte 1 iken 1 olarak tahmin ediyorsak True Pozitif*<br>
# *Sınıf değerimiz 1 iken 0 olarak tahmin ediyorsak True Negatif*<br>
# *Sınıf değerimiz 0 iken 1 olarak tahmin ediyorsak False Pozitif*<br>
# *Sınıf değerimiz 0 iken 0 olarak tahmin ediyorsak False Negatif*

# %% [markdown]
# *Daha yüksek kesinlik ve anma değerlerine sahip modeller daha başarılı kabul edilir.*

# %% [markdown]
# #### ROC Eğrileri

# %% [markdown]
# <div align="center">
#     <img src="image XVII.png" width="500">
# </div>

# %% [markdown]
# *Bir veya birden fazla sınıflandırıcının başarısının değerlendirilmesi için kullanılan bir tekniktir.*
