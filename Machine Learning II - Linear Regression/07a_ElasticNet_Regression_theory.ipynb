# %% [markdown]
# ## ElasticNet Regression (Teori)

# %% [markdown]
# *Burada amaç yine Lasso ve Ridge Regresyon'da olduğu gibi hata kareler toplamını minimize eden katsayıları bu katsayılara ceza işlemi uygulayarak bulmaktır. L1 ve L2 yaklaşımlarını birleştirir.*

# %% [markdown]
# <div align="center">
#     <img src="ENet-I.png" width="500">
# </div>

# %% [markdown]
# - *Lasso tarzı cezalandırma, Ridge tarzı değişken seçimi*
# - *Lineer Regresyon'un en modern halidir.(En etkilidir demek değildir. Sadece son hali olarak düşünülebilir.)*
# - *Düzenlileştirme, Çok boyutluluğu önleme, çoklu doğrusal bağlantı problemini ortadan kaldırma.*
