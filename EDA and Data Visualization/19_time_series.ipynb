# %% [markdown]
# ### Basit Zaman Serisi Grafiği

# %%
import pandas as pd
import yfinance as yf
# Out:
# C:\Users\tcmur\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# ### Veri Seti Hikayesi

# %% [markdown]
# *High = Hisse senedinin en yüksek değeri*<br>
# *Low = Hisse senedinin en düşük değeri*<br>
# *Open = Hissenin açılış değeri*<br>
# *Close = Hissenin kapanış değeri*<br>
# *Volume = Hissenin hacmi*<br>

# %%
df = yf.download("AAPL", start = "2016-01-01", end = "2016-08-25")
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2016-01-04  23.730953  23.735459  22.976339  23.113746  270597600
# 2016-01-05  23.136267  23.843577  23.068690  23.821052  223164000
# 2016-01-06  22.683496  23.059679  22.496534  22.651960  273829600
# 2016-01-07  21.726152  22.555103  21.721648  22.228479  324377600
# 2016-01-08  21.841030  22.325335  21.795979  22.199191  283192000

# %%
df.shape
# Out:
# (163, 5)

# %%
kapanis = df["Close"]
kapanis.head()
# Out:
# Ticker           AAPL
# Date
# 2016-01-04  23.730953
# 2016-01-05  23.136267
# 2016-01-06  22.683496
# 2016-01-07  21.726152
# 2016-01-08  21.841030

# %%
kapanis.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# *Tarih-Zaman değişkenleri ile çalışırken bazen bu değişkenler zaman değişkeni olarak tanımlanmayabiliyor. Bu durumda el ile zaman değişkenlerini tanımlamamız gerekir. Şu an çalıştığımız veri setinde zaman değişkeni tanımlandığı için buna gerek yok fakat gerek olsaydı aşağıdaki gibi bir kod yazardık:*

# %%
kapanis.index = pd.DatetimeIndex(kapanis.index)

# %%
kapanis.index
# Out:
# DatetimeIndex(['2016-01-04', '2016-01-05', '2016-01-06', '2016-01-07',
#                '2016-01-08', '2016-01-11', '2016-01-12', '2016-01-13',
#                '2016-01-14', '2016-01-15',
#                ...
#                '2016-08-11', '2016-08-12', '2016-08-15', '2016-08-16',
#                '2016-08-17', '2016-08-18', '2016-08-19', '2016-08-22',
#                '2016-08-23', '2016-08-24'],
#               dtype='datetime64[s]', name='Date', length=163, freq=None)

# %%
kapanis.head()
# Out:
# Ticker           AAPL
# Date
# 2016-01-04  23.730953
# 2016-01-05  23.136267
# 2016-01-06  22.683496
# 2016-01-07  21.726152
# 2016-01-08  21.841030
