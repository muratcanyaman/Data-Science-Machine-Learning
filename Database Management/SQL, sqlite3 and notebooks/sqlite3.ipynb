# %% [markdown]
# #### sqlite3

# %%
import sqlite3
import pandas as pd

# %%
 conn = sqlite3.connect('sql.db')

# %%
# ?conn
# Out:
# Signature:   conn(*args, **kwargs)
# Type:        Connection
# String form: <sqlite3.Connection object at 0x0000029DCB9684F0>
# File:        c:\users\muratcan\anaconda3\envs\datascience\lib\sqlite3\__init__.py
# Docstring:   SQLite database connection object.

# %%
c = conn.cursor()

# %%
#read_sql

# %%
pd.read_sql("""SELECT COUNT(CustomerID) AS MUSTERI_SAYISI, Country AS ULKE 
               FROM Customers 
               GROUP BY Country;""", conn)
# Out:
#     MUSTERI_SAYISI         ULKE
# 0                3    Argentina
# 1                2      Austria
# 2                2      Belgium
# 3                9       Brazil
# 4                3       Canada
# 5                2      Denmark
# 6                2      Finland
# 7               11       France
# 8               11      Germany
# 9                1      Ireland
# 10               3        Italy
# 11               5       Mexico
# 12               1       Norway
# 13               1       Poland
# 14               2     Portugal
# 15               5        Spain
# 16               2       Sweden
# 17               2  Switzerland
# 18               7           UK
# 19              13          USA
# 20               4    Venezuela

# %%
df = pd.read_sql("""SELECT COUNT(CustomerID) AS MUSTERI_SAYISI, Country AS ULKE 
               FROM Customers 
               GROUP BY Country;""", conn)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#conn.close()

# %%
c.execute("SELECT CustomerName FROM Customers LIMIT 5;")

# %%
c.fetchone()
# Out:
# ('Alfreds Futterkiste',)

# %%
c.fetchall()
# Out:
# [('Ana Trujillo Emparedados y helados',),
#  ('Antonio Moreno Taquería',),
#  ('Around the Horn',),
#  ('Berglunds snabbköp',)]

# %%
for row in c.execute("SELECT CustomerName FROM Customers LIMIT 5;"):
    print(row)
# Out:
# ('Alfreds Futterkiste',)
# ('Ana Trujillo Emparedados y helados',)
# ('Antonio Moreno Taquería',)
# ('Around the Horn',)
# ('Berglunds snabbköp',)
