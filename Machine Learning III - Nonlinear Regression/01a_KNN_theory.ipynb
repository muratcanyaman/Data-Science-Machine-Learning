# %% [markdown]
# ## K-En Yakın Komşu (Teori)

# %% [markdown]
# - *Tahminler gözlem benzerliğine göre yapılır.*
# - *Bana gözlemini söyle sana kim olduğunu söyleyeyim.*
# - *İlk başta sınıflandırma problemi için bir çözüm olarak ortaya çıkmış, daha sonra regresyon problemlerine uyarlanmıştır.*
# - *Büyük veri setlerinde yüksek performans sağlamaz.*

# %% [markdown]
# <div align="center">
#     <img src="attachment:KNN-I.png" width="600">
# </div>

# %% [markdown]
# ## KNN Basamakları

# %% [markdown]
# - *Komşu sayısı belirle(K).*
# - *Bilinmeyen nokta ile diğer tüm noktalar arasındaki uzaklıkları hesapla.*
# - *Uzaklıkları sırala ve belirlenen k sayısına göre en yakın olan k gözlemi seç.*
# - *Sınıflandırma ise en sık sınıf, regresyon ise ortalama değeri tahmin değeri olarak ver.*
