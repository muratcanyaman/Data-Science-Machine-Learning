# %% [markdown]
# ## XGBOOST (TEORİ)

# %% [markdown]
# *XGBoost, GBM'nin hız ve tahmin performansını arttırmak üzere optimize edilmiş, ölçeklenebilir ve farklı platformlara entegre edilebilir halidir. Kaggle'da meşhurdur.*

# %% [markdown]
# - *R, Python, Hadoop, Scala, Julia ile kullanılabilir.*
# - *Ölçeklenebilirdir.*
# - *Hızlıdır.*
# - *Tahmin başarısı yüksektir.*
# - *Bir çok kaggle yarışmasında başarısını kanıtlamıştır.*

# %% [markdown]
# *2017'ye kadar popülerliğini korudu. Yandex'in XGBoost'a alternatif olarak sunduğu LightGBM ve Catboost yayınlandıktan sonra eskisi gibi çok konuşulmasa da başarılı bir algoritma olduğu gerçeğini halen koruyor.*
