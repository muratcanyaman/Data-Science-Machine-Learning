# %% [markdown]
# ## LightGBM (Model)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, log_loss
from sklearn.metrics import roc_auc_score, roc_curve
from lightgbm import LGBMClassifier
from warnings import filterwarnings
filterwarnings('ignore')

# %%
diabetes = pd.read_csv('diabetes.csv')
df = diabetes.copy()
df.dropna()
y = df['Outcome']
X = df.drop(['Outcome'], axis = 1)
X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                    test_size = 0.30,
                                                    random_state = 42)

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
lgbm_model = LGBMClassifier(verbose = -1, n_jobs = 1).fit(X_train, y_train)

# %%
#test hatasi

# %%
y_pred = lgbm_model.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7229437229437229

# %% [markdown]
# ## Model Tuning

# %%
lgbm_params = {
    "n_estimators" : [100,500,1000,2000],
    "subsample" : [0.6,0.8,1.0],
    "max_depth" : [3,4,5,6],
    "learning_rate" : [0.1,0.01,0.02,0.05],
    "min_child_samples" : [5,10,20]}

# %%
lgbm = LGBMClassifier(verbose = -1, n_jobs = 1)

lgbm_cv = GridSearchCV(lgbm,
                       lgbm_params,
                       cv = 10,
                       n_jobs = -1,
                       verbose = 2)

# %%
lgbm_cv.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 576 candidates, totalling 5760 fits
# GridSearchCV(cv=10, estimator=LGBMClassifier(n_jobs=1, verbose=-1), n_jobs=-1,
#              param_grid={'learning_rate': [0.1, 0.01, 0.02, 0.05],
#                          'max_depth': [3, 4, 5, 6],
#                          'min_child_samples': [5, 10, 20],
#                          'n_estimators': [100, 500, 1000, 2000],
#                          'subsample': [0.6, 0.8, 1.0]},
#              verbose=2)

# %%
lgbm_cv.best_params_
# Out:
# {'learning_rate': 0.05,
#  'max_depth': 3,
#  'min_child_samples': 20,
#  'n_estimators': 100,
#  'subsample': 0.6}

# %%
#final model

# %%
lgbm_tuned = LGBMClassifier(learning_rate = 0.05,
                            max_depth = 3,
                            min_child_samples = 20,
                            n_estimators = 100,
                            subsample = 0.6,
                           verbose = -1,
                            n_jobs = 1)

# %%
lgbm_tuned.fit(X_train, y_train)
# Out:
# LGBMClassifier(learning_rate=0.05, max_depth=3, n_jobs=1, subsample=0.6,
#                verbose=-1)

# %%
#final test hatasi

# %%
y_pred = lgbm_tuned.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7489177489177489
