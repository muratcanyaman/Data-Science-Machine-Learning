# %% [markdown]
# ## Karar Ağaçları (CART) - Teori

# %% [markdown]
# *Amaç veri seti içerisindeki karmaşık yapıları basit karar yapılarına dönüştürmektir. Heterojen veri setleri belirlenmiş bir hedef değişkene göre homojen alt gruplara ayrılır.*

# %% [markdown]
# <div align="center">
#     <img src="CART-I.png" width="500">
# </div>

# %% [markdown]
# *Yukarıdaki ağaca benzer bir ağaca ait yorumlamalarımızı Doğrusal Olmayan Regresyon bölümünde detaylıca ele almıştık. Benzer bir yorumlama işlemini Sınıflandırma Problemi için yapalım.*

# %% [markdown]
# *Yukarıdaki görselde iki değişken neticesinde bir sınıf tahmini yapılmış. Boy 180 cm'den büyük ise cinsiyeti erkek olarak tahminle. Eğer 180'den küçük veya eşit ise araya bir değişken daha giriyor, kiloya bakıyoruz. Kilo 80 kg'den büyük ise cinsiyeti erkek olarak tahmin yap, değilse kadın olarak tahmin yap.*
