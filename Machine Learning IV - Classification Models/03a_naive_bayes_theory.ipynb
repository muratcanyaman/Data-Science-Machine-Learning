# %% [markdown]
# ## Naive Bayes (Teori)

# %% [markdown]
# *Olasılık temelli bir modelleme tekniğidir. Amaç belirli bir örneğin her bir sınıfa ait olma olasılığının koşullu olasılık temelli hesaplanmasıdır.*

# %% [markdown]
# *E-Ticaret gibi çok kategorili sınıf yapılarının bulunduğu veya ilgilenilen yanıt değişkeninin çok sınıflı olduğu senaryolarda bayes olasılık temelli yaklaşımları etkili bir şekilde çalışır.*

# %% [markdown]
# <div align="center">
#     <img src="bayes-I.png" width="500">
# </div>
